# %%
import pandas as pd
import requests

# %%
aus_url = 	'http://popdata.unhcr.org/api/stats/asylum_seekers_monthly.json?year=2015,2016&month=8&coa=SRB&coo=SYR'

# %%
data = requests.get(aus_url)
data.content
# Out:
# b'[{"country_of_asylum":"SRB","country_of_asylum_en":"Serbia and Kosovo: S/RES/1244 (1999)","country_of_origin":"SYR","country_of_origin_en":"Syrian Arab Rep.","year":2015,"month":8,"month_en":"August","value":3}]'

# %%
stats  = data.content.decode("utf-8")

# %%
import json 
stats = json.loads(data.content)
print([json.dumps(stats)])
# Out:
# ['[{"country_of_asylum": "SRB", "country_of_asylum_en": "Serbia and Kosovo: S/RES/1244 (1999)", "country_of_origin": "SYR", "country_of_origin_en": "Syrian Arab Rep.", "year": 2015, "month": 8, "month_en": "August", "value": 3}]']

# %%
pd.read_json('http://popdata.unhcr.org/api/stats/resettlement.json?year=2014&country_of_asylum=AUS')
# Out:
#    country_of_asylum country_of_asylum_en country_of_origin  \
# 0                AUS            Australia               AFG
# 1                AUS            Australia               ARE
# 2                AUS            Australia               BDI
# 3                AUS            Australia               BEN
# 4                AUS            Australia               BTN
# 5                AUS            Australia               CHN
# 6                AUS            Australia               CIV
# 7                AUS            Australia               COD
# 8                AUS            Australia               COG
# 9                AUS            Australia               DJI
# 10               AUS            Australia               DZA
# 11               AUS            Australia               EGY
# 12               AUS            Australia               ERI
# 13               AUS            Australia               ETH
# 14               AUS            Australia               GHA
# 15               AUS            Australia               GIN
# 16               AUS            Australia               IDN
# 17               AUS            Australia               IND
# 18               AUS            Australia               IRN
# 19               AUS            Australia               IRQ
# 20               AUS            Australia               JOR
# 21               AUS            Australia               KEN
# 22               AUS            Australia               KWT
# 23               AUS            Australia               LBN
# 24               AUS            Australia               LBR
# 25               AUS            Australia               LBY
# 26               AUS            Australia               LKA
# 27               AUS            Australia               MMR
# 28               AUS            Australia               MWI
# 29               AUS            Australia               MYS
# 30               AUS            Australia               NPL
# 31               AUS            Australia               PAK
# 32               AUS            Australia               PSE
# 33               AUS            Australia               RWA
# 34               AUS            Australia               SAU
# 35               AUS            Australia               SDN
# 36               AUS            Australia               SLE
# 37               AUS            Australia               SOM
# 38               AUS            Australia               SSD
# 39               AUS            Australia               SYR
# 40               AUS            Australia               TGO
# 41               AUS            Australia               THA
# 42               AUS            Australia               TIB
# 43               AUS            Australia               TUR
# 44               AUS            Australia               TZA
# 45               AUS            Australia               UGA
# 46               AUS            Australia               VEN
# 47               AUS            Australia               VNM
# 48               AUS            Australia               ZAF
# 49               AUS            Australia               ZMB
# 50               AUS            Australia               ZWE
#
#                   country_of_origin_en  value  year
# 0                          Afghanistan   1874  2014
# 1                 United Arab Emirates     10  2014
# 2                              Burundi     48  2014
# 3                                Benin      3  2014
# 4                               Bhutan    315  2014
# 5                                China      4  2014
# 6                        Côte d'Ivoire     28  2014
# 7               Dem. Rep. of the Congo    216  2014
# 8                                Congo      3  2014
# 9                             Djibouti      6  2014
# 10                             Algeria      1  2014
# 11                               Egypt    105  2014
# 12                             Eritrea    277  2014
# 13                            Ethiopia    176  2014
# 14                               Ghana      6  2014
# 15                              Guinea     14  2014
# 69               USA  United States of America               ZAF
# 70               USA  United States of America               ZWE
#
#                                  country_of_origin_en  value  year
# 0                                         Afghanistan    696  2014
# 1                                             Armenia     45  2014
# 2                                          Azerbaijan     21  2014
# 3                                             Burundi    133  2014
# 4                                          Bangladesh      2  2014
# 5                                             Belarus     60  2014
# 6                                              Bhutan   7476  2014
# 7                                Central African Rep.    200  2014
# 8                                               China     50  2014
# 9                                       Côte d'Ivoire     39  2014
# 10                                           Cameroon      9  2014
# 11                             Dem. Rep. of the Congo   5128  2014
# 12                                              Congo     58  2014
# 13                                           Colombia    461  2014
# 14                                               Cuba   3703  2014
# 15                                            Ecuador     23  2014
# 16                                              Egypt     17  2014
# 17                                            Eritrea   1409  2014
# 18                                           Ethiopia    687  2014
# 19                                              Gabon      3  2014
# 20  United Kingdom of Great Britain and Northern I...      1  2014
# 21                                            Georgia     15  2014
# 22                                              Ghana      2  2014
# 23                                             Guinea     10  2014
# 24                                             Gambia      1  2014
# 25                                              Haiti      4  2014
# 26                                          Indonesia     18  2014
# 27                                              India     23  2014
# 28                             Iran (Islamic Rep. of)   2830  2014
# 29                                               Iraq  20337  2014
# ..                                                ...    ...   ...
# 41                                            Morocco      1  2014
# 42              The former Yugoslav Rep. of Macedonia    241  2014
# 43                                               Mali      2  2014
# 44                                            Myanmar  15971  2014
# 45                                         Mauritania      4  2014
# 46                                              Nepal    126  2014
# 47                                           Pakistan    229  2014
# 48                                        Philippines      4  2014
# 49                        Dem. People's Rep. of Korea     15  2014
# 50                                        Palestinian    140  2014
# 51                                 Russian Federation    198  2014
# 52                                             Rwanda     51  2014
# 53                                       Saudi Arabia      2  2014
# 54                                              Sudan   1043  2014
# 55                                          Singapore      3  2014
# 56                                       Sierra Leone     10  2014
# 57                                            Somalia  10057  2014
# 58                                   Syrian Arab Rep.    271  2014
# 59                                               Chad     31  2014
# 60                                               Togo     25  2014
# 61                                           Thailand      8  2014
# 62                                       Turkmenistan      2  2014
# 63                                            Tunisia      2  2014
# 64                                             Uganda     22  2014
# 65                                            Ukraine    667  2014
# 66                                         Uzbekistan     65  2014
# 67                                           Viet Nam     80  2014
# 68                                              Yemen     14  2014
# 69                                       South Africa      3  2014
# 70                                           Zimbabwe      3  2014
#
# [71 rows x 6 columns]

# %%
pd.read_json('http://popdata.unhcr.org/api/stats/resettlement.json?year=2014&country_of_asylum=DEU')
# Out:
#   country_of_asylum country_of_asylum_en country_of_origin  \
# 0               DEU              Germany               AFG
# 1               DEU              Germany               CHN
# 2               DEU              Germany               ETH
# 3               DEU              Germany               IRN
# 4               DEU              Germany               IRQ
# 5               DEU              Germany               LKA
# 6               DEU              Germany               SDN
# 7               DEU              Germany               SOM
# 8               DEU              Germany               SSD
# 9               DEU              Germany               STA
#
#      country_of_origin_en  value  year
# 0             Afghanistan     16  2014
# 1                   China      3  2014
# 2                Ethiopia      1  2014
# 3  Iran (Islamic Rep. of)      6  2014
# 4                    Iraq    103  2014
# 5               Sri Lanka     59  2014
# 6                   Sudan      2  2014
# 7                 Somalia     31  2014
# 8             South Sudan      1  2014
# 9               Stateless     58  2014

# %%
df = pd.read_json('http://popdata.unhcr.org/api/stats/resettlement.json?year=2014&country_of_asylum=FRA')

# %%
df
# Out:
#    country_of_asylum country_of_asylum_en country_of_origin  \
# 0                FRA               France               AFG
# 1                FRA               France               BDI
# 2                FRA               France               CAF
# 3                FRA               France               CIV
# 4                FRA               France               COD
# 5                FRA               France               COG
# 6                FRA               France               ETH
# 7                FRA               France               IRN
# 8                FRA               France               IRQ
# 9                FRA               France               KAZ
# 10               FRA               France               LKA
# 11               FRA               France               NPL
# 12               FRA               France               PSE
# 13               FRA               France               RUS
# 14               FRA               France               RWA
# 15               FRA               France               SDN
# 16               FRA               France               SOM
# 17               FRA               France               SYR
# 18               FRA               France               TCD
#
#       country_of_origin_en  value  year
# 0              Afghanistan     18  2014
# 1                  Burundi      1  2014
# 2     Central African Rep.      1  2014
# 3            Côte d'Ivoire      4  2014
# 4   Dem. Rep. of the Congo     12  2014
# 5                    Congo      1  2014
# 6                 Ethiopia      4  2014
# 7   Iran (Islamic Rep. of)      1  2014
# 8                     Iraq      2  2014
# 9               Kazakhstan      1  2014
# 10               Sri Lanka      3  2014
# 11                   Nepal      1  2014
# 12             Palestinian      3  2014
# 13      Russian Federation      3  2014
# 14                  Rwanda      7  2014
# 15                   Sudan      2  2014
# 16                 Somalia      5  2014
# 17        Syrian Arab Rep.     40  2014
# 18                    Chad      1  2014

# %%
import arcgis
from arcgis.gis import GIS
from IPython.display import display

# %%
gis = GIS("http://slustl.maps.arcgis.com/home", "gregbrunner_slugis")
# Out:
# Enter password: ········

# %%
resettlment_stats = gis.content.import_data(df, {"Address" : "country_of_origin_en"})

# %%
map  =  gis.map('England', zoomlevel=7)
map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
map.add_layer(resettlment_stats, { "renderer":"ClassedSizeRenderer", "field_name":"value" })

# %%
resettlment_stats.query().df
# Out:
#     ObjectId country_of_asylum country_of_asylum_en country_of_origin  \
# 0          1               FRA               France               AFG
# 1          2               FRA               France               BDI
# 2          3               FRA               France               CAF
# 3          4               FRA               France               CIV
# 4          5               FRA               France               COD
# 5          6               FRA               France               COG
# 6          7               FRA               France               ETH
# 7          8               FRA               France               IRN
# 8          9               FRA               France               IRQ
# 9         10               FRA               France               KAZ
# 10        11               FRA               France               LKA
# 11        12               FRA               France               NPL
# 12        13               FRA               France               PSE
# 13        14               FRA               France               RUS
# 14        15               FRA               France               RWA
# 15        16               FRA               France               SDN
# 16        17               FRA               France               SOM
# 17        18               FRA               France               TCD
#
#       country_of_origin_en  value  year  \
# 0              Afghanistan     18  2014
# 1                  Burundi      1  2014
# 2     Central African Rep.      1  2014
# 3            Côte d'Ivoire      4  2014
# 4   Dem. Rep. of the Congo     12  2014
# 5                    Congo      1  2014
# 6                 Ethiopia      4  2014
# 7   Iran (Islamic Rep. of)      1  2014
# 8                     Iraq      2  2014
# 9               Kazakhstan      1  2014
# 10               Sri Lanka      3  2014
# 11                   Nepal      1  2014
# 12             Palestinian      3  2014
# 13      Russian Federation      3  2014
# 14                  Rwanda      7  2014
# 15                   Sudan      2  2014
# 16                 Somalia      5  2014
# 17                    Chad      1  2014
#
#                                                 SHAPE
# 0   {'x': 7349837.296999998, 'y': 4006150.33429999...
# 1   {'x': 3331396.2041000016, 'y': -370044.6110999...
# 2   {'x': -6410163.564099999, 'y': -2919775.608100...
# 3   {'x': -618349.5579000004, 'y': 851797.52149999...
# 4   {'x': 2628888.2291, 'y': -318749.5758000016, '...
# 5   {'x': 1695985.2120000012, 'y': -91481.61540000...
# 6   {'x': 4413233.397100002, 'y': 963111.951699998...
# 7   {'x': 4481939.772300001, 'y': 5004042.44370000...
# 8   {'x': 4873252.5419000015, 'y': 3900478.3422999...
# 9   {'x': 7480118.2469, 'y': 6137371.416599996, 's...
# 10  {'x': 8983330.668499999, 'y': 850505.467399999...
# 11  {'x': 9344621.5324, 'y': 3281684.584399998, 's...
# 12  {'x': 3918967.5766000003, 'y': 3751859.3574, '...
# 13  {'x': 10776324.665199999, 'y': 8856659.7117, '...
# 14  {'x': 3334721.4657999985, 'y': -222505.4270999...
# 15  {'x': 3340607.6521999985, 'y': 1810890.7159999...
# 16  {'x': 5143306.1217, 'y': 490803.27809999883, '...
# 17  {'x': 2078798.6218999997, 'y': 1732601.8244000...

# %%
sdf = resettlment_stats.query().df

# %%
reset_map = gis.content.import_data(sdf, title='UNHCR Resettlements in France')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    1625             res = self._combine_const(other, func,
#    1626                                       errors='ignore',
# -> 1627                                       try_cast=False)
#    1628             return res.fillna(True).astype(bool)
#    1629
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func, errors, try_cast)
#    4778                                    errors=errors,
#    4779                                    try_cast=try_cast)
# -> 4780         return self._constructor(new_data)
#    4781
#    4782     def _compare_frame(self, other, func, str_rep):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\features\_data\geodataset\geodataframe.py in __init__(self, *args, **kwargs)
#     240             if isinstance(self['SHAPE'], (GeoSeries, pd.Series)):
#     241                 if all(isinstance(x, _types.Geometry) for x in self[self._geometry_column_name]) == False:
# --> 242                     geometry = [_types.Geometry(g) for g in self['SHAPE'].tolist()]
#     243                     del self['SHAPE']
#     244                     self.set_geometry(geometry, inplace=True)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\features\_data\geodataset\geodataframe.py in <listcomp>(.0)
#     240             if isinstance(self['SHAPE'], (GeoSeries, pd.Series)):
#     241                 if all(isinstance(x, _types.Geometry) for x in self[self._geometry_column_name]) == False:
# --> 242                     geometry = [_types.Geometry(g) for g in self['SHAPE'].tolist()]
#     243                     del self['SHAPE']
#     244                     self.set_geometry(geometry, inplace=True)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\geometry\_types.py in __call__(cls, iterable, **kwargs)
#     135                 iterable = iterable.JSON
#     136         if cls is Geometry:
# --> 137             if len(iterable) > 0:
#     138                 if isinstance(iterable, dict):
#     139                     if 'x' in iterable and \
#
# TypeError: object of type 'bool' has no len()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    1625             res = self._combine_const(other, func,
#    1626                                       errors='ignore',
# -> 1627                                       try_cast=False)
#    1628             return res.fillna(True).astype(bool)
#    1629
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func, errors, try_cast)
#    4778                                    errors=errors,
#    4779                                    try_cast=try_cast)
# -> 4780         return self._constructor(new_data)
#    4781
#    4782     def _compare_frame(self, other, func, str_rep):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\features\_data\geodataset\geodataframe.py in __init__(self, *args, **kwargs)
#     240             if isinstance(self['SHAPE'], (GeoSeries, pd.Series)):
#     241                 if all(isinstance(x, _types.Geometry) for x in self[self._geometry_column_name]) == False:
# --> 242                     geometry = [_types.Geometry(g) for g in self['SHAPE'].tolist()]
#     243                     del self['SHAPE']
#     244                     self.set_geometry(geometry, inplace=True)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\features\_data\geodataset\geodataframe.py in <listcomp>(.0)
#     240             if isinstance(self['SHAPE'], (GeoSeries, pd.Series)):
#     241                 if all(isinstance(x, _types.Geometry) for x in self[self._geometry_column_name]) == False:
# --> 242                     geometry = [_types.Geometry(g) for g in self['SHAPE'].tolist()]
#     243                     del self['SHAPE']
#     244                     self.set_geometry(geometry, inplace=True)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\geometry\_types.py in __call__(cls, iterable, **kwargs)
#     135                 iterable = iterable.JSON
#     136         if cls is Geometry:
# --> 137             if len(iterable) > 0:
#     138                 if isinstance(iterable, dict):
#     139                     if 'x' in iterable and \
#
# TypeError: object of type 'bool' has no len()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    1625             res = self._combine_const(other, func,
#    1626                                       errors='ignore',
# -> 1627                                       try_cast=False)
#    1628             return res.fillna(True).astype(bool)
#    1629
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func, errors, try_cast)
#    4778                                    errors=errors,
#    4779                                    try_cast=try_cast)
# -> 4780         return self._constructor(new_data)
#    4781
#    4782     def _compare_frame(self, other, func, str_rep):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\features\_data\geodataset\geodataframe.py in __init__(self, *args, **kwargs)
#     240             if isinstance(self['SHAPE'], (GeoSeries, pd.Series)):
#     241                 if all(isinstance(x, _types.Geometry) for x in self[self._geometry_column_name]) == False:
# --> 242                     geometry = [_types.Geometry(g) for g in self['SHAPE'].tolist()]
#     243                     del self['SHAPE']
#     244                     self.set_geometry(geometry, inplace=True)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\features\_data\geodataset\geodataframe.py in <listcomp>(.0)
#     240             if isinstance(self['SHAPE'], (GeoSeries, pd.Series)):
#     241                 if all(isinstance(x, _types.Geometry) for x in self[self._geometry_column_name]) == False:
# --> 242                     geometry = [_types.Geometry(g) for g in self['SHAPE'].tolist()]
#     243                     del self['SHAPE']
#     244                     self.set_geometry(geometry, inplace=True)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\geometry\_types.py in __call__(cls, iterable, **kwargs)
#     135                 iterable = iterable.JSON
#     136         if cls is Geometry:
# --> 137             if len(iterable) > 0:
#     138                 if isinstance(iterable, dict):
#     139                     if 'x' in iterable and \
#
# TypeError: object of type 'bool' has no len()

# %%
new_map = gis.map()
new_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
new_map.add_layer(reset_map, { "renderer":"ClassedSizeRenderer", "field_name":"value" })

# %%
usa_df = pd.read_json('http://popdata.unhcr.org/api/stats/resettlement.json?year=2014&country_of_asylum=USA')

# %%
usa_df
# Out:
#    country_of_asylum      country_of_asylum_en country_of_origin  \
# 0                USA  United States of America               AFG
# 1                USA  United States of America               ARM
# 2                USA  United States of America               AZE
# 3                USA  United States of America               BDI
# 4                USA  United States of America               BGD
# 5                USA  United States of America               BLR
# 6                USA  United States of America               BTN
# 0                                         Afghanistan    696  2014
# 1                                             Armenia     45  2014
# 2                                          Azerbaijan     21  2014
# 3                                             Burundi    133  2014
# 4                                          Bangladesh      2  2014
# 5                                             Belarus     60  2014
# 6                                              Bhutan   7476  2014
# 7                                Central African Rep.    200  2014
# 8                                               China     50  2014
# 9                                       Côte d'Ivoire     39  2014
# 10                                           Cameroon      9  2014
# 11                             Dem. Rep. of the Congo   5128  2014
# 12                                              Congo     58  2014
# 13                                           Colombia    461  2014
# 14                                               Cuba   3703  2014
# 15                                            Ecuador     23  2014
# 16                                              Egypt     17  2014
# 17                                            Eritrea   1409  2014
# 18                                           Ethiopia    687  2014
# 19                                              Gabon      3  2014
# 20  United Kingdom of Great Britain and Northern I...      1  2014
# 21                                            Georgia     15  2014
# 22                                              Ghana      2  2014
# 23                                             Guinea     10  2014
# 24                                             Gambia      1  2014
# 25                                              Haiti      4  2014
# 26                                          Indonesia     18  2014
# 27                                              India     23  2014
# 28                             Iran (Islamic Rep. of)   2830  2014
# 29                                               Iraq  20337  2014
# ..                                                ...    ...   ...
# 40                                          Sri Lanka     68  2014
# 41                                            Morocco      1  2014
# 42              The former Yugoslav Rep. of Macedonia    241  2014
# 43                                               Mali      2  2014
# 44                                            Myanmar  15971  2014
# 45                                         Mauritania      4  2014
# 46                                              Nepal    126  2014
# 47                                           Pakistan    229  2014
# 48                                        Philippines      4  2014
# 49                        Dem. People's Rep. of Korea     15  2014
# 50                                        Palestinian    140  2014
# 51                                 Russian Federation    198  2014
# 52                                             Rwanda     51  2014
# 53                                       Saudi Arabia      2  2014
# 54                                              Sudan   1043  2014
# 55                                          Singapore      3  2014
# 56                                       Sierra Leone     10  2014
# 57                                            Somalia  10057  2014
# 58                                               Chad     31  2014
# 59                                               Togo     25  2014
# 60                                           Thailand      8  2014
# 61                                       Turkmenistan      2  2014
# 62                                            Tunisia      2  2014
# 63                                             Uganda     22  2014
# 64                                            Ukraine    667  2014
# 65                                         Uzbekistan     65  2014
# 66                                           Viet Nam     80  2014
# 67                                              Yemen     14  2014
# 68                                       South Africa      3  2014
# 69                                           Zimbabwe      3  2014
#
#                                                 SHAPE
# 0   {'x': 7349837.296999998, 'y': 4006150.33429999...
# 1   {'x': 5002722.552499998, 'y': 4908624.42499999...
# 2   {'x': 5290871.5066, 'y': 4908197.851800002, 's...
# 3   {'x': 3331396.2041000016, 'y': -370044.6110999...
# 4   {'x': 10050864.7128, 'y': 2729624.355900001, '...
# 5   {'x': 3122522.3343, 'y': 7083928.456, 'spatial...
# 6   {'x': 10066201.987599999, 'y': 3175395.1653999...
# 7   {'x': -6410163.564099999, 'y': -2919775.608100...
# 8   {'x': 11569437.687399998, 'y': 4378971.0939999...
# 9   {'x': -618349.5579000004, 'y': 851797.52149999...
# 10  {'x': 1417973.1237999983, 'y': 632475.05799999...
# 11  {'x': 2628888.2291, 'y': -318749.5758000016, '...
# 12  {'x': 1695985.2120000012, 'y': -91481.61540000...
# 13  {'x': -8134755.827500001, 'y': 434606.15190000...
# 14  {'x': -8849899.5181, 'y': 2511525.2347999997, ...
# 15  {'x': -8769219.4427, 'y': -159073.81720000133,...
# 16  {'x': 3325168.2776000015, 'y': 3062667.8011000...
# 17  {'x': 4325949.652600002, 'y': 1731046.95989999...
# 18  {'x': 4413233.397100002, 'y': 963111.951699998...
# 19  {'x': 1311539.5117000006, 'y': -69454.05469999...
# 20  {'x': -219250.36549999937, 'y': 7058898.565099...
# 21  {'x': -9289003.079, 'y': 3848717.4228999987, '...
# 22  {'x': -139124.02070000023, 'y': 891327.3944000...
# 23  {'x': -1218113.6270999983, 'y': 1168144.863400...
# 24  {'x': -1712198.5797999986, 'y': 1510963.021800...
# 25  {'x': -8061386.829299999, 'y': 2154935.9151000...
# 26  {'x': 12681056.085099999, 'y': -110191.5372000...
# 27  {'x': 8843590.6582, 'y': 2677963.1317000017, '...
# 28  {'x': 4481939.772300001, 'y': 5004042.44370000...
# 29  {'x': 4873252.5419000015, 'y': 3900478.3422999...
# ..                                                ...
# 40  {'x': 8983330.668499999, 'y': 850505.467399999...
# 41  {'x': -556597.4539999999, 'y': 3763310.6270999...
# 42  {'x': 2417361.396899998, 'y': 5102847.34139999...
# 43  {'x': -391897.11290000007, 'y': 1963118.469799...
# 44  {'x': 10743654.047200002, 'y': 2406783.7716000...
# 45  {'x': -1150096.0623000003, 'y': 2303798.607999...
# 46  {'x': 9344621.5324, 'y': 3281684.584399998, 's...
# 47  {'x': 7815752.985599998, 'y': 3544012.30030000...
# 48  {'x': 13454255.108, 'y': 1593137.6396999992, '...
# 49  {'x': 2061977.6070999987, 'y': 5229636.7884000...
# 50  {'x': 3918967.5766000003, 'y': 3751859.3574, '...
# 51  {'x': 10776324.665199999, 'y': 8856659.7117, '...
# 52  {'x': 3334721.4657999985, 'y': -222505.4270999...
# 53  {'x': 4959152.743799999, 'y': 2768204.5044, 's...
# 54  {'x': 3340607.6521999985, 'y': 1810890.7159999...
# 55  {'x': 11556800.932999998, 'y': 150678.71040000...
# 56  {'x': -1312682.9730999991, 'y': 956238.6911999...
# 57  {'x': 5143306.1217, 'y': 490803.27809999883, '...
# 58  {'x': 2078798.6218999997, 'y': 1732601.8244000...
# 59  {'x': 108474.61699999869, 'y': 954101.21429999...
# 60  {'x': 11244631.0323, 'y': 1702664.9294999987, ...
# 61  {'x': 6587359.0243999995, 'y': 4749406.4403999...
# 62  {'x': 1069615.1636000015, 'y': 4044431.4042000...
# 63  {'x': 3599594.3988000005, 'y': 168535.68769999...
# 64  {'x': 3492640.7919000015, 'y': 6279426.7185000...
# 65  {'x': 7060091.7223000005, 'y': 5098471.8944000...
# 66  {'x': 12003951.386100002, 'y': 1824032.1678000...
# 67  {'x': 5298134.5711, 'y': 1793747.6873000003, '...
# 68  {'x': 2792454.985800002, 'y': -3375287.4081999...
# 69  {'x': 3326702.470400002, 'y': -2156843.9395999...
#
# [70 rows x 8 columns]

# %%
usa_sdf = resettlment_stats.query().df

# %%
reset_map = gis.content.import_data(usa_sdf, title='UNHCR Resettlements in USA')

# %%
usa_map = gis.map()
usa_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
usa_map.add_layer(reset_map,  { "renderer":"ClassedSizeRenderer", "field_name":"value" })
