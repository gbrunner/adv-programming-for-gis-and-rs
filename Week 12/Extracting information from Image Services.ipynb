# %% [markdown]
# # Sea Temperature Image Service

# %%
from arcgis.features import SpatialDataFrame
from arcgis.raster import ImageryLayer
from arcgis.geometry import Geometry
from arcgis.gis import GIS

gis = GIS()

# %%
img_svc ="https://sampleserver6.arcgisonline.com/arcgis/rest/services/ScientificData/SeaTemperature/ImageServer"
img_lyr = ImageryLayer(img_svc)#, gis=gis)

# %% [markdown]
# # Let's put this layer on a map
# ## Depth = 4

# %%
map_4 = gis.map()
map_4
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %%
selected_4 = img_lyr.filter_by(where="StdZ = -4")

# %%
map_4.add_layer(selected_4)

# %%
the_geom = Geometry(map_4.extent)
s4_samps = selected_4.get_samples(the_geom, sample_count=img_lyr.properties.maxImageHeight, return_first_value_only=False)

# %%
s4_samps[0]['values']
# Out:
# [2.525]

# %% [markdown]
# # What rasters were filtered?

# %%
#selected_4.filtered_rasters()

# %% [markdown]
# ## Depth = 150

# %%
selected_150 = img_lyr.filter_by(where="StdZ = -150")#, geometry=the_geom)

# %%
map_150 = gis.map()
map_150
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %%
map_150.add_layer(selected_150)

# %%
the_geom = Geometry(map_150.extent)
s150_samps = selected_150.get_samples(the_geom, sample_count=img_lyr.properties.maxImageHeight, return_first_value_only=False)

# %%
s150_samps[0]['values']
# Out:
# [2.525]

# %% [markdown]
# ## Depth = 1250

# %%
selected_1250 = img_lyr.filter_by(where="StdZ = -1250")#, geometry=the_geom)

# %% [markdown]
# # Temperature at Depth of 4

# %%
selected_4
# Out:
# <ImageryLayer url:"https://sampleserver6.arcgisonline.com/arcgis/rest/services/ScientificData/SeaTemperature/ImageServer">

# %% [markdown]
# # Temperature at Depth of 150

# %%
selected_150
# Out:
# <ImageryLayer url:"https://sampleserver6.arcgisonline.com/arcgis/rest/services/ScientificData/SeaTemperature/ImageServer">

# %% [markdown]
# # Temperature at Depth of 1250

# %%
selected_1250
# Out:
# <ImageryLayer url:"https://sampleserver6.arcgisonline.com/arcgis/rest/services/ScientificData/SeaTemperature/ImageServer">

# %%
s1250_samps = selected_1250.get_samples(the_geom, sample_count=img_lyr.properties.maxImageHeight, return_first_value_only=False)

# %% [markdown]
# # What Rasters were filtered?

# %% [markdown]
# # Let's Create a Pixel Profile - Ocean Temp as a Function of Depth

# %%
img_sdf = img_lyr.query().df

# %%
img_sdf.head()
# Out:
#    Category       CenterX       CenterY     Dimensions  \
# 0         1  5.684342e-14  5.684342e-14  StdTime, StdZ
# 1         1  5.684342e-14  5.684342e-14  StdTime, StdZ
# 2         1  5.684342e-14  5.684342e-14  StdTime, StdZ
# 3         1  5.684342e-14  5.684342e-14  StdTime, StdZ
# 4         1  5.684342e-14  5.684342e-14  StdTime, StdZ
#
#                           GroupName  HighPS  LowPS  MaxPS  MinPS  \
# 0  374D92CB923FA36D5FC1671135624EEC    0.08   0.08      2      0
# 1  E3C284936B86AF1824615DA6DB8A4001    0.08   0.08      2      0
# 2  AC4E2C5D9479A0C1C34B1654007F30C4    0.08   0.08      2      0
# 3  7153862BAFD00BD1FF65449693A2B0E1    0.08   0.08      2      0
# 4  487FF566AD8D5ACFCFB86080DFD4C9CD    0.08   0.08      2      0
#
#                                                 Name  OBJECTID ProductName  \
# 0  hycom_glb_911_2014040700_t000_ts3z.nc:water_te...         1      NetCDF
# 1  hycom_glb_911_2014040700_t000_ts3z.nc:water_te...         2      NetCDF
# ...

# %%
len(img_sdf)
# Out:
# 1000

# %%
time = 1396828800000
t0_sdf = img_sdf[img_sdf.StdTime==time]

# %%
len(t0_sdf)
# Out:
# 40

# %%
depth = []
for idx,row in enumerate(t0_sdf.iterrows()):
    print(row[1]['StdZ'])
    depth.append(float(row[1]['StdZ']))
# Out:
# 0
# -2
# -4
# -6
# -8
# -10
# -12
# -15
# -20
# -25
# -30
# -35
# -40
# -45
# -50
# -60
# -70
# -80
# -90
# -100
# -125
# -150
# -200
# -250
# -300
# -350
# -400
# -500
# -600
# -700
# -800
# -900
# -1000
# -1250
# -1500
# -2000
# -2500
# -3000
# -4000
# -5000

# %%
from arcgis.geometry import Point

temperatures = []
for idx,row in enumerate(t0_sdf.iterrows()):
    print("StdZ = "+str(row[1]['StdZ']))
    #pixel_location = Point({"x" : -1.028714269305154E7, "y" : 1.0187890995779932E7, "spatialReference" : {"wkid" : 102100}})
    # -5,059,736.486  2,913,876.614
    selected = img_lyr.filter_by(where="StdZ = "+str(row[1]['StdZ']))
    
    pixel_location = Point({"x" : 0, "y" : 0, "spatialReference" : {"wkid" : 4326}})
    t = time
    pixel = selected.identify(geometry=pixel_location, time_extent=t)
    temperatures.append(float(pixel['value']))
# Out:
# StdZ = 0
# StdZ = -2
# StdZ = -4
# StdZ = -6
# StdZ = -8
# StdZ = -10
# StdZ = -12
# StdZ = -15
# StdZ = -20
# StdZ = -25
# StdZ = -30
# StdZ = -35
# StdZ = -40
# StdZ = -45
# StdZ = -50
# StdZ = -60
# StdZ = -70
# StdZ = -80
# StdZ = -90
# StdZ = -100
# StdZ = -125
# StdZ = -150
# StdZ = -200
# StdZ = -250
# StdZ = -300
# StdZ = -350
# StdZ = -400
# StdZ = -500
# StdZ = -600
# StdZ = -700
# StdZ = -800
# StdZ = -900
# StdZ = -1000
# StdZ = -1250
# StdZ = -1500
# StdZ = -2000
# StdZ = -2500
# StdZ = -3000
# StdZ = -4000
# StdZ = -5000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d0a8c2fce4aa> in <module>()
#      11     t = time
#      12     pixel = selected.identify(geometry=pixel_location, time_extent=t)
# ---> 13     temperatures.append(float(pixel['value']))
#
# ValueError: could not convert string to float: 'NoData'

# %%
len(temperatures)
# Out:
# 39

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.plot(temperatures[:39],depth[:39],  "--b",label='linear') #indicde 0 is max
plt.xlabel('Temperature (C)')
plt.ylabel('Depth')
# Out:
# Text(0,0.5,'Depth')
